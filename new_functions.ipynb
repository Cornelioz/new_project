# %%
def sum(x,y):
    """this function will expect 2 arguments, and it will return"""
    return x+y
# Out:
# Hello

# %%
def division(x,y):
    """this fucntion will divide 2 numeric values"""
    return x/y
